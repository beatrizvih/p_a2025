# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizvih/p_a2025/blob/main/termo/termo_em_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

tentativas = 6

palavras = ['jhean', 'pedro', 'lucas', 'bruno', 'carla']

palavra = random.choice(palavras)

letras = []
for letra in palavra:
    letras.append(letra)

qtd_letras = len(letras)

(f'Tente adivinhar um nome com {qtd_letras} letras!')

while tentativas > 0 :
    chute = input(f'\nVocê tem {tentativas} tentativas. Digite um nome com {qtd_letras} letras: ').lower()

    qtd_chute = len(chute)

    while qtd_chute != qtd_letras:
        chute = input(f'\nVocê tem {tentativas} tentativas. Digite um nome com {qtd_letras} letras: ').lower()
        qtd_chute = len(chute)


    resultado = []


    for i in range(qtd_letras):
        if chute[i] == letras[i]:

            resultado.append(chute[i].upper())

        elif chute[i] in letras:

            resultado.append(chute[i])
        else:

            resultado.append('_')
    tentativas -=1

    print('O Resultado é: ', ' '.join(resultado))

    if chute == palavra:
        print('Parabéns! Você acertou a palavra!')

        break

    if tentativas == 0:
        print(f'Você perdeu! A palavra correta era: {palavra}')
