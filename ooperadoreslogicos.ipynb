# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizvih/p_a2025/blob/main/ooperadoreslogicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("digite um numero"))
if num % 2 == 0:
  print('o numero é par')
else:
    print('o numero é impar')
# Out:
# digite um numero5
# o numero é impar

# %%
usuario = str(input('digite o seu nome:'))

if (usuario == "beatriz"):
  print("o usuario corresponde:")
else:
  print("o usuario não coresponde:")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-7b58b7f6d5f1> in <cell line: 0>()
# ----> 1 usuario = str(input('digite o seu nome:'))
#       2
#       3 if (usuario == "beatriz"):
#       4   print("o usuario corresponde:")
#       5 else:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# #ano bissexto

# %%
ano = int(input("qual é o ano?"))
if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
  print("é um ano bissexto.")
else:
  print("o ano não é bissexto.")
# Out:
# qual é o ano?2036
# é um ano bissexto.

# %% [markdown]
# #menor ou maoir de idade

# %%
idade = int(input("qual é a sua idade:"))
if  idade >=18:
 print("voce é maior de idade")
else:
  print("voce é menor de idade")
# Out:
# qual é a sua idade:18
# voce é maior de idade
