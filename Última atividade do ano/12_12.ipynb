# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizvih/p_a2025/blob/main/%C3%9Altima%20atividade%20do%20ano/12_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1 - Condicional Simples
#
# Crie um programa que pergunte ao usuário se ele já montou sua árvore de Natal.
#
# Se a resposta for "sim", exiba uma mensagem motivacional.
#
# Se a resposta for "não", exiba uma mensagem encorajando-o a montar a árvore hoje.

# %%
resposta = input("Você já montou sua árvore de Natal? (sim/não): ").lower()

if resposta == "sim":
    print("Que ótimo! O clima de Natal deixa tudo mais especial ")
else:
    print("Ainda dá tempo! Que tal montar sua árvore hoje e entrar no clima natalino? ")
# Out:
# Você já montou sua árvore de Natal? (sim/não): Sim
# Que ótimo! O clima de Natal deixa tudo mais especial

# %% [markdown]
# Exercício 2 - Laço de Repetição
#
# Peça ao usuário um número N e imprima uma contagem regressiva de N até 1, simulando um cronômetro para a chegada do Natal.

# %%
n = int(input("Digite um número para a contagem regressiva até o Natal: "))

for i in range(n, 0, -1):
    print(i)

print("Feliz Natal!")
# Out:
# Digite um número para a contagem regressiva até o Natal: 5
# 5
# 4
# 3
# 2
# 1
# Feliz Natal!

# %% [markdown]
# Exercício 3 - Funções + Lista + Condicional
#
# Crie uma função chamada verificar_presentes(lista_presentes) que recebe uma lista de presentes desejados para o Natal.
#
# A função deve:
#
# 1. Verificar se a lista tem pelo menos 3 itens.
#
# 2. Exibir uma mensagem adequada:
#
# Se tiver 3 ou mais itens → "O Papai Noel terá trabalho este ano!"
#
# Caso contrário → "Sua lista está muito curta!"
#
# 3. Retornar a quantidade total de presentes.

# %%
def verificar_presentes(lista_presentes):
    if len(lista_presentes) >= 3:
        print("O Papai Noel terá trabalho este ano!")
    else:
        print("Sua lista está muito curta!")

    return len(lista_presentes)


presentes = ["boneca", "livro", "bicicleta"]
quantidade = verificar_presentes(presentes)

print("Quantidade total de presentes:", quantidade)
# Out:
# O Papai Noel terá trabalho este ano!
# Quantidade total de presentes: 3

# %% [markdown]
# Exercício 4 - Funções + Dicionário + Laços
#
# Crie uma função contar_enfeites(enfeites) que recebe um dicionário onde:
#
# chave → tipo de enfeite de Natal
#
# valor → quantidade daquele enfeite
#
# A função deve percorrer o dicionário usando um laço de repetição, somar todas as as quantidades e retornar o total de enfeites.

# %%
def contar_enfeites(enfeites):
    total = 0
    for tipo, quantidade in enfeites.items():
        total += quantidade
    return total


enfeites_natal = {
    "bolas": 20,
    "pisca-pisca": 5,
    "laços": 8,
    "estrelas": 3
}

total_enfeites = contar_enfeites(enfeites_natal)
print("Total de enfeites de Natal:", total_enfeites)
# Out:
# Total de enfeites de Natal: 36

# %% [markdown]
# Exercício 5 - Função Completa (listas, dicionários, laço e condicional)
#
# Crie um sistema simples para organizar uma ceia de Natal:
#
# 1. Peça ao usuário os pratos que cada pessoa da família vai levar (use laço para cadastrar). 2. Armazene os dados em um dicionário, onde:
#
# chave → nome da pessoa
#
# valor → lista de pratos que ela levará
#
# 3. Crie a função resumo_ceia(dados) que deve mostrar:
#
# Quantas pessoas irão contribuir
#
# Quantos pratos no total serão levados
#
# Se houver mais de 10 pratos, exiba: "Essa ceia vai ser farta!"

# %%
def resumo_ceia(dados):
    total_pessoas = len(dados)
    total_pratos = 0

    for pratos in dados.values():
        total_pratos += len(pratos)

    print("Pessoas que irão contribuir:", total_pessoas)
    print("Total de pratos da ceia:", total_pratos)

    if total_pratos > 10:
        print("Essa ceia vai ser farta!")


# Programa principal
ceia = {}

qtd_pessoas = int(input("Quantas pessoas da família vão contribuir com a ceia? "))

for i in range(qtd_pessoas):
    nome = input(f"\nDigite o nome da pessoa {i + 1}: ")
    qtd_pratos = int(input(f"Quantos pratos {nome} vai levar? "))

    pratos = []
    for j in range(qtd_pratos):
        prato = input(f"Digite o prato {j + 1}: ")
        pratos.append(prato)

    ceia[nome] = pratos


# Chamando a função
resumo_ceia(ceia)
