# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizvih/p_a2025/blob/main/atividade_1_carro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##entrada
carro = 25000
##processamento
imposto = (carro * 45/100)+ carro
valordist = (imposto * 28/100)+ imposto
##saida
print (f"o valor final do carro é {valordist:.2f}" )
# Out:
# o valor final do carro é 46400.00
