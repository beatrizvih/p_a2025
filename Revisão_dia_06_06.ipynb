# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizvih/p_a2025/blob/main/Revis%C3%A3o_dia_06_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Negativo, positivo ou igual a zero

# %%
numero = float(input("digite um numero:"))
if numero >0:
  print("ele é positivo")
if numero <0:
  print("ele é negativo")
if numero==0:
  print("ele é igual a zero")
# Out:
# digite um numero:-6
# ele é negativo

# %% [markdown]
# ##Par ou impar

# %%
numero = float(input("digite um numero:"))
if numero%2 == 0:
  print("o numero é par")
else:
  print("ele é impar")
# Out:
# digite um numero:4
# o numero é par

# %% [markdown]
# ##Verificar maioridade

# %%
idade = float(input("digite sua idade:"))
if idade>18:
  print("voce é de maioridade")
else:
  print("voce é de menoridade")
# Out:
# didgite sua idade:21
# voce é de maioridade

# %% [markdown]
# ##Senha correta

# %%
senha = int(input("digite sua senha:"))
senha1 = 1234
if senha==senha1:
  print("senha correta")
else:
  print("senha incorreta")
# Out:
# digite sua senha:1234
# senha correta

# %% [markdown]
# ##Nota e aprovação

# %%
nota = int(input("digite a sua nota:"))
if nota >=6:
  print("voce está aprovado")
else:
  print("voce esta reprovado")
# Out:
# digite a sua nota:7
# voce está aprovado

# %% [markdown]
# ##Multiplo de 3 ou 5

# %%
numero = float(input("digite um numero:"))
if numero%5 or 3:
  print("ele é multiplo de 5")
else:
  print("ele não é nada lmaoo")
# Out:
# digite um numero:30
# ele é multiplo de 5

# %% [markdown]
# ##Numero dentro do intervalo

# %%
numero = int(input("digite o numero:"))
if 10<= numero <= 20:
  print("ele esta no intervalo")
else:
  print("ele não é nada lmaoo")
# Out:
# digite o numero:7
# ele não é nada lmaoo

# %% [markdown]
# ##Triangulo

# %%
#entrada
l1 = int(input("digite o valor do primeiro lado:"))
l2 = int(input("digite o valor do segundo lado:"))
l3 = int(input("digite o valor do terceiro lado:"))
#processamento
forma_triangulo = (l1 + l2 > l3) and (l1 + l3 > l2) and (l3 + l2 > l1)

equilatero = forma_triangulo and (l1 == l2 == l3)
escaleno = forma_triangulo and ((l1 == l2) or (l1 == l3) or (l2 == l3))
isosceles = forma_triangulo and not equilatero and not isosceles
#saida
print(f"forma um triangulo? {forma_triangulo}")
print(f"todos os lados são iguais? {escaleno}")
print(f"todos os lados diferentes? {isosceles}")
print(f"dois lados iguais? {equilatero}")
