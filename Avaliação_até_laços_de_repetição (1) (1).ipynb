# %% [markdown]
# **Beatriz Vitoria de Oliveira Alencar: **

# %% [markdown]
# 1)Crie um programa em python que imprima números pares
#
# a) Pedir o usuário para digitar uma lista com mínimo 10 números
#
# b) Criar uma nova somente com numeros pares
#
# c) Imprimir números pares

# %%
numeros_pares = []
for i in range (10):
    numeros = int(input("digite numeros"))
    if numeros % 2 ==0:
        numeros_pares.append(numeros)
        print(numeros_pares)
# Out:
# digite numeros 1
# digite numeros 2
# [2]
# digite numeros 3
# digite numeros 4
# [2, 4]
# digite numeros 5
# digite numeros 6
# [2, 4, 6]
# digite numeros 7
# digite numeros 8
# [2, 4, 6, 8]
# digite numeros 9
# digite numeros 10
# [2, 4, 6, 8, 10]

# %% [markdown]
# 2)Crie um programa que conte quantas vezes cada palavra aparece em uma frase.
#
# Pedir ao usuário para digitar uma frase. Imprimir a palavra e quantas vezes ela aparece

# %%
frase = input("Digite uma frase: ").lower()
palavras = frase.split()
contagem = {}

for pl in palavras:
    if pl in contagem:
         contagem[pl]+=1
    else:
         contagem[pl]=1
print("A contagem das palavras é: ")
for pl, qtd in contagem.items():
    print(f"a palavra {pl} acontece essa quantidade :{qtd}")
# Out:
# Digite uma frase:  amo ele amo
# A contagem das palavras é:
# a palavra amo acontece essa quantidade :2
# a palavra ele acontece essa quantidade :1

# %% [markdown]
# 3)Crie um programa em Python para avaliar um desfile de candidatas. O programa deve:
#
# a) Perguntar quantas candidatas vão participar.
#
# b) Perguntar o nome de cada candidata.
#
# c) Para cada candidata, receber 3 notas (uma de cada jurado).
#
# d) Somar as notas e guardar o total em um dicionário, onde a chave é o nome da candidata e o valor é a soma das notas.
#
# Mostrar ao final:
#
# a) A pontuação total de cada candidata.
#
# b) O nome da vencedora (a que tiver a maior pontuação).

# %%
maior = ""
candidata = 0
notas = {}
total = 0
quantidade = int(input("quantas candidatas?:"))
for i in range (quantidade):
    nome = input(f"digite o nome {i + 1} das candidatas:")

for j in range (quantidade):
    nota = float(input(f"digite nota{j + 1} para {nome}:"))
    total += nota
    notas[nome] = total
print("resultado")
for candidata, pontos in notas.items():
    print(f"{candidata}: {pontos} pontos")
vencedora = max(notas, key = notas.get)
print(f"quem venceu foi {vencedora}, com o total de todos ps pontos{maior}pontos")
# Out:
# quantas candidatas?: 2
# digite o nome 1 das candidatas: ana
# digite o nome 2 das candidatas: joana
# digite nota1 para joana: 4
# digite nota2 para joana: 7
# resultado
# joana: 11.0 pontos
# quem venceu foi joana, com pontos
